# %% [markdown]
# <a href="https://colab.research.google.com/github/san88806/NUMPY-PRACTISE/blob/main/machine_learning_linear_regression_project_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Reading and Understanding the Data
# Let's start with the following steps:
#
# 1.Importing data using the pandas library
# 2.Understanding the structure of the data

# %%
df=pd.read_csv(r"C:\Users\Sangeeta\Downloads\CarDataSet.csv")
df
# Out:
#       Unnamed: 0                                               Name  \
# 0              0                             Maruti Wagon R LXI CNG
# 1              1                   Hyundai Creta 1.6 CRDi SX Option
# 2              2                                       Honda Jazz V
# 3              3                                  Maruti Ertiga VDI
# 4              4                    Audi A4 New 2.0 TDI Multitronic
# ...          ...                                                ...
# 7248        1229                  Volkswagen Vento Diesel Trendline
# 7249        1230                             Volkswagen Polo GT TSI
# 7250        1231                             Nissan Micra Diesel XV
# 7251        1232                             Volkswagen Polo GT TSI
# 7252        1233  Mercedes-Benz E-Class 2009-2013 E 220 CDI Avan...
#
#         Location  Year  Kilometers_Driven Fuel_Type Transmission Owner_Type  \
# ...

# %% [markdown]
# 1.Collect and preprocess the data: Collect data on the mileage and sale prices of used cars. Preprocess the data by cleaning it, handling missing values, and transforming it as necessar

# %% [markdown]
# # removeing the 'Unnamed' column and storing this in df1.

# %%
df1=df.iloc[:,1:]
df1
# Out:
#                                                    Name    Location  Year  \
# 0                                Maruti Wagon R LXI CNG      Mumbai  2010
# 1                      Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2                                          Honda Jazz V     Chennai  2011
# 3                                     Maruti Ertiga VDI     Chennai  2012
# 4                       Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# ...                                                 ...         ...   ...
# 7248                  Volkswagen Vento Diesel Trendline   Hyderabad  2011
# 7249                             Volkswagen Polo GT TSI      Mumbai  2015
# 7250                             Nissan Micra Diesel XV     Kolkata  2012
# 7251                             Volkswagen Polo GT TSI        Pune  2013
# 7252  Mercedes-Benz E-Class 2009-2013 E 220 CDI Avan...       Kochi  2014
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage  \
# ...

# %%
#print the first 10 rows 
df1.head(10)
# Out:
#                                   Name    Location  Year  Kilometers_Driven  \
# 0               Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1     Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                         Honda Jazz V     Chennai  2011              46000
# 3                    Maruti Ertiga VDI     Chennai  2012              87000
# 4      Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
# 5      Hyundai EON LPG Era Plus Option   Hyderabad  2012              75000
# 6               Nissan Micra Diesel XV      Jaipur  2013              86999
# 7    Toyota Innova Crysta 2.8 GX AT 8S      Mumbai  2016              36000
# 8  Volkswagen Vento Diesel Comfortline        Pune  2013              64430
# 9       Tata Indica Vista Quadrajet LS     Chennai  2012              65932
#
#   Fuel_Type Transmission Owner_Type     Mileage   Engine      Power  Seats  \
# ...

# %% [markdown]
# # To get the summary of the dataframe, dtype, memory usage

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7253 entries, 0 to 7252
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               7253 non-null   object
#  1   Location           7253 non-null   object
#  2   Year               7253 non-null   int64
#  3   Kilometers_Driven  7253 non-null   int64
#  4   Fuel_Type          7253 non-null   object
#  5   Transmission       7253 non-null   object
#  6   Owner_Type         7253 non-null   object
#  7   Mileage            7251 non-null   object
#  8   Engine             7207 non-null   object
#  9   Power              7207 non-null   object
#  10  Seats              7200 non-null   float64
#  11  New_Price          1006 non-null   object
#  12  Price              6019 non-null   float64
# dtypes: float64(2), int64(2), object(9)
# memory usage: 736.8+ KB

# %% [markdown]
# # To getting the numbers of unique count in columns

# %%
for i in df1.columns:
    print(f"Unique {i}'s count:{df1[i].nunique()}")
    print(f"{df1[i].unique()}\n")
# Out:
# Unique Name's count:2041
# ['Maruti Wagon R LXI CNG' 'Hyundai Creta 1.6 CRDi SX Option'
#  'Honda Jazz V' ... 'Ford EcoSport 1.5 Petrol Ambiente'
#  'Jeep Compass 1.4 Sport' 'Hyundai Elite i20 Magna Plus']
#
# Unique Location's count:11
# ['Mumbai' 'Pune' 'Chennai' 'Coimbatore' 'Hyderabad' 'Jaipur' 'Kochi'
#  'Kolkata' 'Delhi' 'Bangalore' 'Ahmedabad']
#
# Unique Year's count:23
# [2010 2015 2011 2012 2013 2016 2018 2014 2017 2007 2009 2008 2019 2006
#  2005 2004 2002 2000 2003 1999 2001 1998 1996]
#
# Unique Kilometers_Driven's count:3660
# [72000 41000 46000 ... 89411 52262 72443]
#
# Unique Fuel_Type's count:5
# ['CNG' 'Diesel' 'Petrol' 'LPG' 'Electric']
#
# Unique Transmission's count:2
# ['Manual' 'Automatic']
#
# Unique Owner_Type's count:4
# ['First' 'Second' 'Fourth & Above' 'Third']
#
# Unique Mileage's count:450
# ['26.6 km/kg' '19.67 kmpl' '18.2 kmpl' '20.77 kmpl' '15.2 kmpl'
#  '21.1 km/kg' '23.08 kmpl' '11.36 kmpl' '20.54 kmpl' '22.3 kmpl'
# ...

# %% [markdown]
# # Getting the count of null values in each coloumn

# %%
df1.isna().sum()
# Out:
# Name                    0
# Location                0
# Year                    0
# Kilometers_Driven       0
# Fuel_Type               0
# Transmission            0
# Owner_Type              0
# Mileage                 2
# Engine                 46
# Power                  46
# Seats                  53
# New_Price            6247
# Price                1234
# dtype: int64

# %% [markdown]
# # Numbr of columns and rows present in dataset

# %%
df1.shape
# Out:
# (7253, 13)

# %% [markdown]
# # Printing index of all columns

# %%
df1.columns
# Out:
# Index(['Name', 'Location', 'Year', 'Kilometers_Driven', 'Fuel_Type',
#        'Transmission', 'Owner_Type', 'Mileage', 'Engine', 'Power', 'Seats',
#        'New_Price', 'Price'],
#       dtype='object')

# %% [markdown]
# # Now changing the the data type object into numeric

# %%
Mlge=df1['Mileage'].str.split(' ',expand=True)
df1['Mileage']=pd.to_numeric(Mlge[0],errors='coerce')

# %%
eng=df1['Engine'].str.split(' ',expand=True)
df1['Engine']=pd.to_numeric(eng[0],errors='coerce')

# %%
pr=df1['Power'].str.split(' ',expand=True)
df1['Power']=pd.to_numeric(pr[0],errors='coerce')

# %%
mean=df1['Price'].mean()
df1['Price'].fillna(mean,inplace=True)

# %%
eng_mean=df1['Engine'].mean()
df1['Engine'].fillna(eng_mean,inplace=True)

# %%
power_mean=df1['Power'].mean()
df1['Power'].fillna(power_mean,inplace=True)

# %%
mileage_mean=df1['Mileage'].mean()
df1['Mileage'].fillna(mileage_mean,inplace=True)

# %%
seat_mean=mean=df1['Seats'].mean()
df1['Seats'].fillna(seat_mean,inplace=True)

# %%
df1
# Out:
#                                                    Name    Location  Year  \
# 0                                Maruti Wagon R LXI CNG      Mumbai  2010
# 1                      Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2                                          Honda Jazz V     Chennai  2011
# 3                                     Maruti Ertiga VDI     Chennai  2012
# 4                       Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# ...                                                 ...         ...   ...
# 7248                  Volkswagen Vento Diesel Trendline   Hyderabad  2011
# 7249                             Volkswagen Polo GT TSI      Mumbai  2015
# 7250                             Nissan Micra Diesel XV     Kolkata  2012
# 7251                             Volkswagen Polo GT TSI        Pune  2013
# 7252  Mercedes-Benz E-Class 2009-2013 E 220 CDI Avan...       Kochi  2014
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type  Mileage  Engine  \
# ...

# %%
df1.isna().sum()
# Out:
# Name                    0
# Location                0
# Year                    0
# Kilometers_Driven       0
# Fuel_Type               0
# Transmission            0
# Owner_Type              0
# Mileage                 0
# Engine                  0
# Power                   0
# Seats                   0
# New_Price            6247
# Price                   0
# dtype: int64

# %% [markdown]
# # Getting the statistical description about data

# %%
df1.describe()
# Out:
#               Year  Kilometers_Driven      Mileage       Engine        Power  \
# count  7253.000000       7.253000e+03  7253.000000  7253.000000  7253.000000
# mean   2013.365366       5.869906e+04    18.141580  1616.573470   112.765214
# std       3.254421       8.442772e+04     4.561567   593.394164    52.844178
# min    1996.000000       1.710000e+02     0.000000    72.000000    34.200000
# 25%    2011.000000       3.400000e+04    15.170000  1198.000000    77.000000
# 50%    2014.000000       5.341600e+04    18.160000  1493.000000    98.600000
# 75%    2016.000000       7.300000e+04    21.100000  1968.000000   138.030000
# max    2019.000000       6.500000e+06    33.540000  5998.000000   616.000000
#
#              Seats        Price
# count  7253.000000  7253.000000
# mean      5.279722     9.479468
# std       0.808688    10.191695
# min       0.000000     0.440000
# 25%       5.000000     3.850000
# 50%       5.000000     6.750000
# 75%       5.000000     9.479468
# ...

# %%
df1.corr()
# Out:
# C:\Users\Sangeeta\AppData\Local\Temp\ipykernel_8688\473017434.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df1.corr()
#                        Year  Kilometers_Driven   Mileage    Engine     Power  \
# Year               1.000000          -0.187859  0.322437 -0.054233  0.012855
# Kilometers_Driven -0.187859           1.000000 -0.069122  0.094765  0.030074
# Mileage            0.322437          -0.069122  1.000000 -0.585023 -0.501818
# Engine            -0.054233           0.094765 -0.585023  1.000000  0.853067
# Power              0.012855           0.030074 -0.501818  0.853067  1.000000
# Seats              0.008137           0.090162 -0.305545  0.399033  0.094826
# Price              0.279449          -0.011318 -0.280510  0.604829  0.704212
#
#                       Seats     Price
# ...

# %%
df2=df1[['Mileage','Price']].dropna()

# %%
df2
# Out:
#       Mileage      Price
# 0       26.60   1.750000
# 1       19.67  12.500000
# 2       18.20   4.500000
# 3       20.77   6.000000
# 4       15.20  17.740000
# ...       ...        ...
# 7248    20.54   9.479468
# 7249    17.21   9.479468
# 7250    23.08   9.479468
# 7251    17.20   9.479468
# 7252    10.00   9.479468
#
# [7253 rows x 2 columns]

# %%
df1.plot.scatter(x='Mileage',y='Price')
# Out:
# <Axes: xlabel='Mileage', ylabel='Price'>

# %% [markdown]
# # now making bar between 'mileage' and 'Price'

# %%
plt.bar(df1['Name'],df1['Mileage'])
plt.legend()
plt.xlabel('name of the brands')
plt.ylabel('Mileage')
plt.title('Name vs Mileage ')
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.bar(df1['Name'],df1['Price'])
plt.legend()
plt.xlabel('Name of the brands')
plt.ylabel('Price')
plt.title('Name vs Price ')
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.bar(df1['Price'],df1['Mileage'])
plt.legend()
plt.xlabel('Price of the brands')
plt.ylabel('Mileage')
plt.title('Price vs Mileage ')
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.figure(figsize=(15,5))
sns.barplot(x='Location',y='Price',data=df)
# Out:
# <Axes: xlabel='Location', ylabel='Price'>

# %%
plt.figure(figsize=(14,5))
sns.barplot(x='Year',y='Price',data=df)
# Out:
# C:\Users\Sangeeta\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\algorithms.py:98: RuntimeWarning: Mean of empty slice
#   boot_dist.append(f(*sample, **func_kwargs))
# <Axes: xlabel='Year', ylabel='Price'>

# %%
import seaborn as sns
sns.pairplot(df1)

# %%
corr=df1.corr()
sns.heatmap(corr,xticklabels=corr.columns,yticklabels=corr.columns,annot=True,cmap=sns.diverging_palette(220,20,as_cmap=True))
# Out:
# C:\Users\Sangeeta\AppData\Local\Temp\ipykernel_8688\2831685613.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr=df1.corr()
# <Axes: >

# %% [markdown]
# # Feature engineering

# %%
from sklearn.model_selection import train_test_split

# %%
Mileage=df2['Mileage'].values.reshape(-1,1)
Price=df2['Price'].values.reshape(-1,1)
plt.scatter(Price,Mileage)

# %% [markdown]
# # performing linear Regresssion for Mileage and Price

# %%
x_train, x_test, y_train, y_test=train_test_split(Mileage,Price,test_size=0.3,random_state=100)

# %%
x_train
# Out:
# array([[21.9 ],
#        [16.47],
#        [16.47],
#        ...,
#        [15.8 ],
#        [22.54],
#        [22.9 ]])

# %%
x_test
# Out:
# array([[18.  ],
#        [22.7 ],
#        [16.47],
#        ...,
#        [17.6 ],
#        [17.05],
#        [16.8 ]])

# %%
y_train
# Out:
# array([[ 7.4       ],
#        [ 6.18      ],
#        [ 2.4       ],
#        ...,
#        [15.5       ],
#        [ 9.47946835],
#        [ 5.65      ]])

# %%
y_test
# Out:
# array([[ 1.75],
#        [ 3.31],
#        [ 3.76],
#        ...,
#        [ 2.99],
#        [13.5 ],
#        [ 7.  ]])

# %%
from sklearn.linear_model import LinearRegression

# %%
reg=LinearRegression()

# %%
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
reg.intercept_
# Out:
# array([20.18488757])

# %%
reg.coef_
# Out:
# array([[-0.5944916]])

# %%
pred_1=reg.predict(x_test)

# %%
pred_1
# Out:
# array([[ 9.48403882],
#        [ 6.68992831],
#        [10.39361096],
#        ...,
#        [ 9.72183546],
#        [10.04880584],
#        [10.19742874]])

# %% [markdown]
# Model

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.metrics import r2_score

# %%
mae=mean_absolute_error(y_test,pred_1)
mse=mean_squared_error(y_test,pred_1)
score=r2_score(y_test,pred_1)

# %%
mae
# Out:
# 5.921634851611915

# %%
mse
# Out:
# 99.2244785482876

# %%
score
# Out:
# 0.09147842367298664

# %%
year=df['Year'].values.reshape(-1,1)
plt.scatter(year,Price)

# %% [markdown]
# #perforing the linear regression for year and price

# %%
x1_train, x1_test, y1_train, y1_test=train_test_split(year,Price,test_size=0.3,random_state=100)

# %%
reg.fit(x1_train,y1_train)
# Out:
# LinearRegression()

# %%
reg.intercept_
# Out:
# array([-1732.10625094])

# %%
reg.coef_
# Out:
# array([[0.86497928]])

# %%
pred_2=reg.predict(x1_test)

# %%
pred_2
# Out:
# array([[ 4.77214608],
#        [12.55695961],
#        [ 9.09704249],
#        ...,
#        [ 8.23206321],
#        [ 8.23206321],
#        [10.82700105]])

# %%
mae1=mean_absolute_error(y1_test,pred_2)
mse1=mean_squared_error(y1_test,pred_2)
score1=r2_score(y1_test,pred_2)

# %%
mae1
# Out:
# 6.082604329870128

# %%
mse1
# Out:
# 100.81080477065659

# %%
score1
# Out:
# 0.07695366505292311
